# %%
# %matplotlib inline
from geopy.geocoders import Nominatim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.basemap import Basemap

# %%
df = pd.read_csv(r"excel_files/top_grossing_by_year1980.csv", header = None)

# %%
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode(df[2][3])

# %%
df[2][3]
# Out:
# 'Los Angeles, Chicago'

# %%
locations = list()
for x in range(10):
    locations.append((geolocator.geocode(df[2][x]))[1])

# %%
# Out:
# []

# %%
fig = plt.figure(figsize=(20, 20))
m = Basemap(projection='cyl', resolution=None, 
            lat_0=1, lon_0=1,)
m.etopo(scale=0.5, alpha=0.5)

# Map (long, lat) to (x, y) for plotting
#x, y = m(-87, 41)
x, y = m(locations[1], locations[0])
plt.plot(x, y, 'ok', markersize=5)
#plt.text(x, y, ' Chicago', fontsize=12);

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode("Perth")
location[1]
# Out:
# (-31.9527121, 115.8604796)
