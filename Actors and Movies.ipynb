# %%
from textblob import TextBlob

# %%
import pandas as pd
import seaborn as sns
from langdetect import detect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-a11ac57a1dfe> in <module>
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 3 from langdetect import detect
#
# ModuleNotFoundError: No module named 'langdetect'

# %% [markdown]
# ### Reading in Data
# Due to the size of the raw data from IMDb, several aspects of the data have been removed to further focus on specifics and so that Jupyter has less trouble handling the Data Frames
#
# #### Actors
# - Missing the birthYear value
# - Birth years before 1900
# - Primary Profession not listing "actor" or "actress"
#
# #### Movies
# - Removing all without a runtime
# - Removing all that are not labeled as 'movie' (i.e. short films, television, etc)

# %%
actors_df = pd.read_csv('actors_data_1900.csv')
movies_df = pd.read_csv('movies_wruntime.csv')

# %%
movies_df.head()
# Out:
#       tconst titleType                    primaryTitle  \
# 0  tt0000009     movie                      Miss Jerry
# 1  tt0000147     movie   The Corbett-Fitzsimmons Fight
# 3  tt0000574     movie     The Story of the Kelly Gang
# 4  tt0000679     movie  The Fairylogue and Radio-Plays
# 5  tt0001184     movie         Don Juan de Serrallonga
#
#                     originalTitle  isAdult startYear  runtimeMinutes  \
# 0                      Miss Jerry        0      1894              45
# 1   The Corbett-Fitzsimmons Fight        0      1897              20
# 3     The Story of the Kelly Gang        0      1906              70
# 4  The Fairylogue and Radio-Plays        0      1908             120
# 5         Don Juan de Serrallonga        0      1910              58
#
#                    genres
# 0                 Romance
# 1  Documentary,News,Sport
# 3   Biography,Crime,Drama
# 4       Adventure,Fantasy
# 5         Adventure,Drama

# %% [markdown]
# ### Data Cleaning
# There are several entries that do not have a start year, so first we will clean it up by removing those. Then it is much easier to compare the years since they will now all be integer values.
# Also since we are not working with any television shows, we can drop the endYear value and relabel the startYear column.

# %%
movies_df = movies_df[(movies_df.startYear !="\\N")].drop(columns = ['endYear'])

# %% [markdown]
# In an effort to remove any films listed that may not be relevant (very small productions, never released to a wide audience or during the turn of the century) generally have missing genre information so I will drop the entires without atleast one genre.

# %%
movies_df = movies_df[movies_df['genres'] !='\\N']

# %% [markdown]
# Now I am curious what the difference between the Original Title and the Primary Title, how often do they not match?

# %%
(movies_df['primaryTitle'] != movies_df['originalTitle']).value_counts()
# Out:
# False    116708
# True      31315
# dtype: int64

# %% [markdown]
# There are 31315 instances of the Primary Title and the Original Title not matching. After looking at the titles of the films, it seems that almost always the English title is considered the Primary Title and the Original Title is in the language of the origin country.

# %%
diffTitle_df = movies_df[movies_df['primaryTitle'] != movies_df['originalTitle']]
diffTitle_df
# Out:
#             tconst titleType                                    primaryTitle  \
# 6        tt0001258     movie                           The White Slave Trade
# 12       tt0001790     movie            Les Misérables, Part 1: Jean Valjean
# 15       tt0001911     movie                                     Nell Gwynne
# 16       tt0001964     movie                                   The Traitress
# 17       tt0002026     movie                    Anny - Story of a Prostitute
# 20       tt0002130     movie                                 Dante's Inferno
# 21       tt0002153     movie                    The Great Circus Catastrophe
# 22       tt0002186     movie                               The Flying Circus
# 28       tt0002452     movie                     The Independence of Romania
# 29       tt0002461     movie          The Life and Death of King Richard III
# 30       tt0002514     movie                                Saved in Mid-Air
# 40       tt0002844     movie       Fantômas: In the Shadow of the Guillotine
# 42       tt0002898     movie                 Germinal; or, The Toll of Labor
# 43       tt0002917     movie                         Brother Against Brother
# 50       tt0003037     movie                      Fantomas: The Man in Black
# 52       tt0003102     movie                                Love Everlasting
# 55       tt0003131     movie                                     War Is Hell
# 99                                      Le faux magistrat        0      1914
# 107                                   Cajus Julius Caesar        0      1914
# 108                                             Der Golem        0      1915
# 110                                              Halvblod        0      1913
# ...                                                   ...      ...       ...
# 160826                                       Surveillance        0      2007
# 160827                                           Yattâman        0      2009
# 160835                                      Chihuo Yuzhou        0      2018
# 160843                                     2 Gisht Mjaltë        0      2019
# 160847                                       Atomin paluu        0      2015
# 160851                           Varg Veum - Falne engler        0      2008
# 160859      Grutarally - Shuvam Shel 'Yeled Ochel MePach'        0      2018
# 160864                       Tabi no okurimono 0:00 hatsu        0      2006
# 160865            Trinadeset kratki opusa za golyam ekran        0      2007
# 160866                            Zhi jian de zhong liang        0      2006
# 160874                                         Densen uta        0      2007
# 160875                               Der große Ausverkauf        0      2007
# 160876                                             Kokoro        0      2007
# 160880                           Ji yin jue ding wo ai ni        0      2007
# 160882  Eiga wa ikimono no kiroku de aru: Tsuchimoto N...        0      2007
# 160883                 Canciones de amor en Lolita's Club        0      2007
# 160887                                        Mal Nascida        0      2007
# 160888                                       Matab sena'y        0      2006
# 160891              Ôgon no hô: Eru Kantâre no rekishikan        0      2003
# 160902                                   Tabaluga und Leo        0      2003
# 160987    Olkas II: Taxidevontas apo kai pros to Vyzantio        0      2017
# 161001                                        Chambre 212        0      2019
# 161100     Nra masin kam te inchpes na chvakhetsav arjits        0      2019
# 161167                          La Strada per le montagne        0      2019
# 161170           O antifasistikos agonas sti Mesi Anatoli        0      2018
# 161219                                              Sekte        0      2019
# 161222                                    Piso den gyrnao        0      2016
# 161233                                   Tri dnya v iyule        0      1978
# 161268                                       Jino to Mari        0      2019
# 161280               Singularidades de uma Rapariga Loura        0      2009
#
#         runtimeMinutes                   genres
# 6                   45                    Drama
# 12                  60                    Drama
# 15                  50  Biography,Drama,History
# 16                  48                    Drama
# 17                  68            Drama,Romance
# 20                  68  Adventure,Drama,Fantasy
# 21                  45                    Drama
# 22                  46                    Drama
# 28                 120              History,War
# 29                  55                    Drama
# 30                  60                    Drama
# 40                  54              Crime,Drama
# 42                 150                    Drama
# 43                  51                    Drama
# 50                  61              Crime,Drama
# 52                  90                    Drama
# 55                  50                Drama,War
# 57                 300                    Drama
# 58                  90      Crime,Drama,Mystery
# 60                  54                    Drama
# 64                 110  Biography,Drama,History
# 67                  85     Drama,Fantasy,Horror
# 71                  88          Adventure,Drama
# 73                  86                    Crime
# 93                  57                    Drama
# 97                  59              Crime,Drama
# 99                  70              Crime,Drama
# 107                112            Drama,History
# 108                 60                   Horror
# 110                 69                    Drama
# ...                ...                      ...
# 160826              87   Drama,Romance,Thriller
# 160827             111  Action,Adventure,Comedy
# 160835              89         Animation,Family
# 160843             101                   Comedy
# 160847             110              Documentary
# 160851              95     Crime,Drama,Thriller
# 160859              67             Comedy,Music
# 160864             109                    Drama
# 160865              75              Documentary
# 160866              90                    Drama
# 160874             128           Horror,Mystery
# 160875              94              Documentary
# 160876              64                    Drama
# 160880              95    Comedy,Romance,Sci-Fi
# 160882              94              Documentary
# 160883             100                    Drama
# 160887             117                    Drama
# 160888             110           Comedy,Romance
# 160891             110                Animation
# 160902              70                Animation
# 160987              59              Documentary
# 161001              86                   Comedy
# 161100             112                    Drama
# 161167              82              Documentary
# 161170              72      Documentary,History
# 161219              89                   Horror
# 161222              63              Documentary
# 161233              68            Drama,Romance
# 161268              91                    Drama
# 161280              64            Drama,Romance
#
# [31315 rows x 8 columns]
