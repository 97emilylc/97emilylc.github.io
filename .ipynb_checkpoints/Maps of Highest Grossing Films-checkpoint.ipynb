# %%
# %matplotlib inline
from geopy.geocoders import Nominatim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.basemap import Basemap

# %%
df = pd.read_csv(r"excel_files/top_grossing_by_year1980.csv", header = None)

# %%
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode(df[2])

# %%
df[2]
# Out:
# 0                                          Space
# 1              800 W 6th Street, Los Angeles, CA
# 2                      Prison, Florence, Arizona
# 3                           Los Angeles, Chicago
# 4                                            NaN
# 5                                         Belgum
# 6                       Butcher Hollow, Kentucky
# 7                                  Dallas, Texas
# 8                                           Fiji
# 9                                        Chicago
# 10                         Lake Forest, Illinois
# 11                                         Malta
# 12                               Pasadena, Texas
# 13    333 E Wonderview Ave, Estes Park, CO 80517
# 14                                   Los Angeles
# 15                                     Hollywood
# 16                           Boca Raton, Florida
# 17                 Cunningham County, New Jersey
# 18                                      Arkansas
# 19                              Atlanta, Georgia
# 20                                 New York City
# 21                     New York City/Los Angeles
# 22                                         Space
# 23                                      Missouri
# 24                                        London
# 25                                  Boise, Idaho
# 26                                      New York
# 27                                       Fantasy
# 28                                   Los Angeles
# 29                                       Chicago
#                          ...
# 70                                           NaN
# 71                                           NaN
# 72                                   Los Angeles
# 73                                        Israel
# 74                                   Los Angeles
# 75                                           NaN
# 76                                           NaN
# 77                               Culver City, CA
# 78                                           NaN
# 79                                        London
# 80                                  Pasadena, CA
# 81                                     Hollywood
# 82                             Staten Island, NY
# 83                                New York State
# 84                                 New York City
# 85                                          Utah
# 86                                    Travelling
# 87                                   South Bronx
# 88                               Long Island, NY
# 89                                         Japan
# 90                                         Texas
# 91                                    Buffalo NY
# 92                                        Mexico
# 93                                 Pacific Ocean
# 94                                       Wyoming
# 95                                 Pacific Ocean
# 96                                   Los Angeles
# 97                                      Acapulco
# 98                                           NaN
# 99                                   Los Angeles
# Name: 2, Length: 100, dtype: object

# %%
fig = plt.figure(figsize=(20, 20))
m = Basemap(projection='cyl', resolution=None, 
            lat_0=1, lon_0=1,)
m.etopo(scale=0.5, alpha=0.5)

# Map (long, lat) to (x, y) for plotting
#x, y = m(-87, 41)
x, y = m(location[1][1], location[1][0])
plt.plot(x, y, 'ok', markersize=5)
plt.text(x, y, ' Chicago', fontsize=12);

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode("")
location[1]
# Out:
# (-35.26562945, 149.130500824092)

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes()


points_with_annotation = []
for i in range(10):
    point, = plt.plot(i, i, 'o', markersize=10)

    annotation = ax.annotate("Mouseover point %s" % i,
        xy=(i, i), xycoords='data',
        xytext=(i + 1, i), textcoords='data',
        horizontalalignment="left",
        arrowprops=dict(arrowstyle="simple",
                        connectionstyle="arc3,rad=-0.2"),
        bbox=dict(boxstyle="round", facecolor="w", 
                  edgecolor="0.5", alpha=0.9)
        )
    # by default, disable the annotation visibility
    annotation.set_visible(False)

    points_with_annotation.append([point, annotation])


def on_move(event):
    visibility_changed = False
    for point, annotation in points_with_annotation:
        should_be_visible = (point.contains(event)[0] == True)

        if should_be_visible != annotation.get_visible():
            visibility_changed = True
            annotation.set_visible(should_be_visible)

    if visibility_changed:        
        plt.draw()

on_move_id = fig.canvas.mpl_connect('motion_notify_event', on_move)

plt.show()
