# %%
# %matplotlib inline
from geopy.geocoders import Nominatim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.basemap import Basemap

# %%
df = pd.read_csv(r"excel_files/top_grossing_by_year1980.csv", header = None)

# %%
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode(df[3][3])

# %%
df[3][3]
# Out:
# 'United States'

# %%
df.head()
# Out:
#      0                        1                                  2  \
# 0  NaN  The Empire Strikes Back                              Space
# 1  2.0                   9 to 5  800 W 6th Street, Los Angeles, CA
# 2  3.0               Stir Crazy          Prison, Florence, Arizona
# 3  4.0                Airplane!               Los Angeles, Chicago
# 4  5.0    Any Which Way You Can                                NaN
#
#                3    4
# 0            NaN  NaN
# 1  United States  NaN
# 2  United States  NaN
# 3  United States  NaN
# 4            NaN  NaN

# %%
df = df.drop(0, axis=1)

# %%
df.columns = {"Title", "Setting", "Country", "Period"}

# %%
df.head()
# Out:
#                    Setting                              Title Period
# 0  The Empire Strikes Back                              Space    NaN
# 1                   9 to 5  800 W 6th Street, Los Angeles, CA    NaN
# 2               Stir Crazy                   Florence Arizona    NaN
# 3                Airplane!                        Los Angeles    NaN
# 4    Any Which Way You Can                                NaN    NaN

# %%
lat = pd.Series()
long = pd.Series()

# %%
geolocator = Nominatim(user_agent='myapplication')
location = geolocator.geocode("Los Angeles")
location[1][1]
# Out:
# -118.2427666

# %%
fig = plt.figure(figsize=(20, 20))
m = Basemap(projection='cyl', resolution=None, 
            lat_0=1, lon_0=1,)
m.etopo(scale=0.5, alpha=0.5)

# Map (long, lat) to (x, y) for plotting
#x, y = m(-87, 41)
x, y = m(location[1][1], location[1][0])
plt.plot(x, y, 'ok', markersize=5)
#plt.text(x, y, ' Chicago', fontsize=12);

# %%
# Out:
# (-31.9527121, 115.8604796)

# %%
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
import geopandas
from shapely.geometry import Point
import matplotlib.pyplot as plt

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
cities = geopandas.read_file(geopandas.datasets.get_path('naturalearth_cities'))

# %%
base = world.plot(color='white', edgecolor='black')

cities.plot(ax=base, marker='o', color='red', markersize=5)

# %%
new_df.head()
# Out:
#      Country  Period  Setting  Title
# 0  Australia       1        1      0
# 1    Belgium       1        1      0
# 2     Brazil       1        1      0
# 3     Canada       1        1      0
# 4       Fiji       1        1      0

# %%
new_df = df.groupby(['Country']).count()
new_df = new_df.reset_index()
new_df = world.merge(new_df,how='left', left_on='name', right_on='Country').drop(["Country", "Setting", "Title"], axis = 1)

# %%
# Out:
# 0      0.500000
# 1      0.500000
# 2      0.500000
# 3      0.500000
# 4      0.500000
# 5      0.500000
# 6      0.500000
# 7      0.500000
# 8      0.499931
# 9      0.500000
# 10     0.500000
# 11     0.500000
# 12     0.499931
# 13     0.500000
# 14     0.500000
# 15     0.500000
# 16     0.500000
# 17     0.500000
# 18     0.500000
# 19     0.500000
# 20     0.500000
# 21     0.500000
# 22     0.499931
# 23     0.500000
# 24     0.500000
# 25     0.500000
# 26     0.500000
# 27     0.499931
# 28     0.500000
# 29     0.500000
#          ...
# 147    0.500000
# 148    0.500000
# 149    0.500000
# 150    0.500000
# 151    0.500000
# 152    0.500000
# 153    0.500000
# 154    0.500000
# 155    0.500000
# 156    0.500000
# 157    0.500000
# 158    0.500000
# 159    0.500000
# 160    0.500000
# 161    0.500000
# 162    0.500000
# 163    0.500000
# 164    0.500000
# 165    0.500000
# 166    0.500000
# 167    0.500000
# 168    0.495868
# 169    0.500000
# 170    0.500000
# 171    0.500000
# 172    0.500000
# 173    0.500000
# 174    0.500000
# 175    0.500000
# 176    0.500000
# Name: Period, Length: 177, dtype: float64

# %%
new_df=new_df.fillna(0)

# %%
new_df["Period"] = (1/(new_df["Period"]))

# %%
new_df.head()
# Out:
#       pop_est      continent                  name iso_a3  gdp_md_est  \
# 0  28400000.0           Asia           Afghanistan    AFG     22270.0
# 1  12799293.0         Africa                Angola    AGO    110300.0
# 2   3639453.0         Europe               Albania    ALB     21810.0
# 3   4798491.0           Asia  United Arab Emirates    ARE    184300.0
# 4  40913584.0  South America             Argentina    ARG    573900.0
#
#                                             geometry    Period
# 0  POLYGON ((61.21081709172574 35.65007233330923,...  0.421697
# 1  (POLYGON ((16.32652835456705 -5.87747039146621...  0.421697
# 2  POLYGON ((20.59024743010491 41.85540416113361,...  0.421697
# 3  POLYGON ((51.57951867046327 24.24549713795111,...  0.421697
# 4  (POLYGON ((-65.50000000000003 -55.199999999999...  0.421697

# %%
fig, ax = plt.subplots(1, 1)

new_df.plot(column='Period',
            ax=ax,
            legend=True,
            legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})
fig.set_size_inches(18.5, 10.5, forward=True)
